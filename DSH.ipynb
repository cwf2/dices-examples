# %% [markdown]
# <div class="well" style="margin:1em 2em">
# <p>This Notebook demonstrates results reported in the DSH article, <a href="https://doi.org/10.1093/llc/fqac006">"Towards a linked open data resource for direct speech acts in Greek and Latin epic"</a></p>
# </div>
#
#
# # Heroes and their moms
#
# Let's say we're young scholars interested in Telemachus' speech to Penelope.
#  - How often does he speak to her?
#  - What kind of language does he use?
#  - How does the narrator refer to these speeches?
#
# We'll start by showing how the DICES database and Python library can be used to retrieve and manipulate the speeches in question. Then we'll expand our perspective to show how DICES enables research on a "distant reading" scale, taking in all heroes and their mothers. Finally, we'll check the accuracy of the automated methods by comparing against a benchmark of hand-curated mother-child speech data.

# %% [markdown]
# ## Preliminaries

# %%
import pandas as pd
from collections import Counter

# %% [markdown]
# ### Install the client library
#
# If you don't have the DICES client library, you can install it with **pip**:
# ```
# pip install git+https://github.com/cwf2/dices-client.git
# ```
#
# ### The DICES API
#
# When you instantiate the API, you can optionally provide endpoints for the DICES database and for a CTS server hosting the texts.
#
# - The default endpoint for DICES is our Uni-Rostock server.
#
# - The default for texts is the [Perseids CTS server](https://cts.perseids.org/).
#
# Finally, just for Jupyter, I'm passing an optional progress bar generator, and sending log messages to a local file.

# %%
from dicesapi import DicesAPI
from dicesapi.jupyter import NotebookPBar

api = DicesAPI(progress_class=NotebookPBar, logfile='dices.log')

# %% [markdown]
# ### CLTK
#
# #### Set up tokenizers, lemmatizers
#
# I like to have one convenience function that I can call on every speech, regardless of language. That means I have to set up language-specific pipelines first.

# %%
from cltk.nlp import NLP

cltk_nlp = {
    'greek': NLP('grc', suppress_banner=True),
    'latin': NLP('lat', suppress_banner=True),    
}

# %%
# trim the pipelines to just normalizing and tokenization for speed
cltk_nlp['greek'].pipeline.processes = cltk_nlp['greek'].pipeline.processes[:2]
cltk_nlp['latin'].pipeline.processes = cltk_nlp['latin'].pipeline.processes[:2]

# %% [markdown]
# ### WikiData
#
# To figure out how characters are related, which isn't in the DICES metadata, I'm going to use [WikiData](https://www.wikidata.org), via the *qwikidata* package.

# %%
from qwikidata.linked_data_interface import get_entity_dict_from_api
from qwikidata.entity import WikidataItem, WikidataProperty

# %% [markdown]
# ##  Part 1
#
# Let's start by building a lexicon for all the words Telemachus speaks to Penelope.
#
# ### Identify and download the speeches
#
# Using the hand-rolled DICES API code, we can search speeches using keywords. For now, JSON results from the API are paged, so if your search has a lot of results, you may have to wait for several pages to download. I've added a progress bar widget because I get impatient.
#
# Note that I can specify both the speaker and the addressee.

# %%
speeches = api.getSpeeches(spkr_name='Telemachus', addr_name='Penelope')

# %% [markdown]
# What did we get?

# %%
for s in speeches:
    print(s)
# Out:
# <Speech 713: Odyssey 1.346-1.359>
# <Speech 1103: Odyssey 17.46-17.56>
# <Speech 1107: Odyssey 17.108-17.149>
# <Speech 1170: Odyssey 18.227-18.242>
# <Speech 1270: Odyssey 21.344-21.353>
# <Speech 1323: Odyssey 23.97-23.103>

# %% [markdown]
# The feature that allows us to connect these to external digital libraries is the passage-specific CTS URN:

#
# Homer Odyssey 23.97-23.103
# μῆτερ ἐμή, δύσμητερ, ἀπηνέα θυμὸν ἔχουσα, τίφθʼ οὕτω πατρὸς νοσφίζεαι, οὐδὲ παρʼ αὐτὸν ἑζομένη μύθοισιν ἀνείρεαι οὐδὲ μεταλλᾷς; οὐ μέν κʼ ἄλλη γʼ ὧδε γυνὴ τετληότι θυμῷ ἀνδρὸς ἀφεσταίη, ὅς οἱ κακὰ πολλὰ μογήσας ἔλθοι ἐεικοστῷ ἔτεϊ ἐς πατρίδα γαῖαν· σοὶ δʼ αἰεὶ κραδίη στερεωτέρη ἐστὶ λίθοιο.

# %% [markdown]
# ### Use CLTK to parse the text
#
# Running the CLTK NLP pipeline on the text of a speech will return a specialized cltk `Doc` object containing the bundled results of all processes in the pipeline. First, we’ll run the appropriate language-specific pipeline on each speech and save the resulting object as a new attribute of the speech.

# %%
pbar = NotebookPBar(max=len(speeches))

for s in speeches:
    s.cltk_doc = cltk_nlp[s.lang](s.text)
    pbar.update()
# Out:
# HBox(children=(IntProgress(value=0, bar_style='info', max=6), Label(value='0/6')))

# %% [markdown]
# CLTK's pipeline gives us lots of information for each speech, including token parsing, and part-of-speech tagging. Let's look at some of the information we get, word-by-word, for the first speech only:

# %%
pd.DataFrame(w for w in speeches[0].cltk_doc).dropna(axis=1, how='all')
# Out:
#      index_token  index_sentence  string  pos   lemma xpos  upos
# 0              0               0   μῆτερ    8   μήτηρ   Nb  NOUN  \
# 1              1               0    ἐμή,   12     ἐγώ   Pp  PRON
# 2              2               0      τί   12     τίς   Pi  PRON
# 3              3               0      τʼ    3      τʼ   Df   ADV
# 4              4               0     ἄρα    3     ἆρα   Df   ADV
# ..           ...             ...     ...  ...     ...  ...   ...
# 98             1               7     γὰρ    3     γάρ   Df   ADV
# 99             2               7  κράτος    8  κράτος   Nb  NOUN
# 100            3               7    ἔστʼ    4    εἰμί   V-   AUX
# 101            4               7     ἐνὶ    2     εἷς   R-   ADP
# 102            5               7   οἴκῳ.    8   οἶκος   Nb  NOUN
#
#     dependency_relation  governor
# 0              vocative         5  \
# 1                  iobj         5
# 2                   obl         5
# 3             discourse         5
# 4             discourse         5
# ..                  ...       ...
# 98            discourse         5
# 99                nsubj         5
# 100                 cop         5
# 101                case         5
# 102                root        -1
#
#                                               features
# 0    [(nominative, accusative, ergative, absolutive...  \
# 1    [(nominative, accusative, ergative, absolutive...
# 2    [(nominative, accusative, ergative, absolutive...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 98                                                  []
# 99   [(nominative, accusative, ergative, absolutive...
# 100  [(admirative, conditional, desiderative, imper...
# 101                                                 []
# 102  [(nominative, accusative, ergative, absolutive...
#
#                                  category
# 0    [(pos, neg), (pos, neg), (pos, neg)]
# 1    [(pos, neg), (pos, neg), (pos, neg)]
# 2    [(pos, neg), (pos, neg), (pos, neg)]
# 3    [(pos, neg), (pos, neg), (pos, neg)]
# 4    [(pos, neg), (pos, neg), (pos, neg)]
# ..                                    ...
# 98   [(pos, neg), (pos, neg), (pos, neg)]
# 99   [(pos, neg), (pos, neg), (pos, neg)]
# 100  [(pos, neg), (pos, neg), (pos, neg)]
# 101  [(pos, neg), (pos, neg), (pos, neg)]
# 102  [(pos, neg), (pos, neg), (pos, neg)]
#
# [103 rows x 11 columns]

# %% [markdown]
# Now let’s go through again and count the lemmata. We’ll create a lemma counter to hold the tallies.

# %%
lems = Counter([w.lemma for s in speeches for w in s.cltk_doc])

# %% [markdown]
# Convert the counter to a Pandas data frame for tidier presentation.

# %%
results = pd.DataFrame(lems.most_common(20), columns=['lemma', 'count'])
results
# Out:
#     lemma  count
# 0     ἐγώ     23
# 1     καί     20
# 2       ὁ     19
# 3      δʼ     17
# 4      οὐ     14
# 5      ὅς     13
# 6      τε      9
# 7      σύ      9
# 8      ἐν      9
# 9    εἰμί      9
# 10    εἰς      8
# 11     δέ      7
# 12    μέν      7
# 13  μήτηρ      6
# 14    γάρ      6
# 15  αὐτός      6
# 16    πᾶς      6
# 17     ὡς      6
# 18    τὶς      5
# 19  οἶκος      5

# %% [markdown]
# A similar table, but for part of speech tags, courtesy of CLTK's NLP pipeline:

# %%
pos = Counter([w.upos for s in speeches for w in s.cltk_doc])
pd.DataFrame(pos.most_common(10), columns=['pos', 'count'])
# Out:
#      pos  count
# 0   NOUN    139
# 1   VERB    136
# 2    ADV    106
# 3   PRON     91
# 4    ADJ     90
# 5  CCONJ     51
# 6  PROPN     29
# 7    ADP     29
# 8    DET     22
# 9  SCONJ      9

# %% [markdown]
# ## Part 2
#
# Now let's think more broadly. How typical is this kind of speech? We can use external linked data to find other examples of mother-son conversations in the corpus.

# %% [markdown]
# ### Some custom code to query WikiData
#
# This lets us ask whether a given addressee belongs to the set of people having a certain relationship to a given speaker. It takes a while to download the WikiData entities, and I had to run this a number of times, so I cached WD data in the respective character objects once it's downloaded.

# %%
def getWD(wd, cache=None):
    '''Return WikiData entity for a given ID'''

    if wd is not None and wd != '':
        if cache is None:
            return WikidataItem(get_entity_dict_from_api(wd))
        else:
            if wd not in cache:
                cache[wd] = WikidataItem(get_entity_dict_from_api(wd))
            return cache[wd]


def checkWDRelation(wd1, wd2, relation, cache=None):
    key = (wd1, wd2, relation)
    if cache is not None and key in cache:
        return cache[key]

    res = False

    wd_ent = getWD(wd1, cache=cache)

    claim_group = wd_ent.get_truthy_claim_group(relation)

    for claim in claim_group:
        if claim.mainsnak.datavalue is not None:
            if claim.mainsnak.datavalue.value['id'] == wd2:
                res = True
    
    if cache is not None:
        cache[key] = res
    return res

# %% [markdown]
# For example, the relation "mother of" has the WikiData ID `'P25'`. Here's how we ask if a given addressee is the mother of a given speaker:

# %%
speaker = api.getCharacters(name='Telemachus')[0]
addressee = api.getCharacters(name='Penelope')[0]

print(f'Is {addressee.name} the mother of {speaker.name}?')
print(checkWDRelation(speaker.wd, addressee.wd, 'P25'))
# Out:
# Is Penelope the mother of Telemachus?
# True

# %% [markdown]
# I also added a separate cache just for the boolean result of checkWDRelation, to save a little more time.

# %%
wd_cache = {}

# %% [markdown]
# ### Using WikiData to filter the speeches
#
# The DICES dataset includes WikiData ids for most of the characters (not all). The DICES API doesn't let us query WikiData itself, though. For now, the easiest thing is just to download all the speeches and character IDs, and then cross reference them against WikiData using its own API.

# %%
# download all the speeches: takes a minute
speeches = (
    api.getSpeeches(work_title='Iliad', progress=True) +
    api.getSpeeches(work_title='Odyssey', progress=True) +    
    api.getSpeeches(author_name='Apollonius', progress=True) +
    api.getSpeeches(author_name='Virgil', progress=True))

speeches.sort()
# Out:
# HBox(children=(IntProgress(value=0, bar_style='info', max=698), Label(value='0/698')))
# HBox(children=(IntProgress(value=0, bar_style='info', max=673), Label(value='0/673')))
# HBox(children=(IntProgress(value=0, bar_style='info', max=143), Label(value='0/143')))
# HBox(children=(IntProgress(value=0, bar_style='info', max=341), Label(value='0/341')))

# %% [markdown]
# **Check each speaker-addressee pair against WikiData**
#
# What we actually do here is download the WikiData entity for each speaker, if we don't already have it cached. Then we ask the WD entity for its mom(s), and check the WD ID of the addressee against the results.

# %%
pbar = NotebookPBar(max=len(speeches))
for s in speeches:
    for inst_list in s.spkr, s.addr:
        for inst in inst_list:
            getWD(inst.wd, cache=wd_cache)
    pbar.update()
# Out:
# HBox(children=(IntProgress(value=0, bar_style='info', max=1855), Label(value='0/1855')))

# %%
# create a dataframe with one row per speech
df = pd.DataFrame(dict(
    id = s.id,
    work = s.work.title,
    l_first = s.l_fi,
    l_last = s.l_la,
    spkr = [inst.name for inst in s.spkr],
    spkr_wd = [inst.wd for inst in s.spkr],
    addr = [inst.name for inst in s.addr],
    addr_wd = [inst.wd for inst in s.addr],
) for s in speeches)

# separate multiple speakers/addressees to give each their own row
df = df.explode(['spkr', 'spkr_wd'])
df = df.explode(['addr', 'addr_wd'])

# create new columns to track motherhood
df[['sp_is_mom','ad_is_mom']] = None

# identify rows where speaker and addressee both have WikiData IDs
mask = df['spkr_wd'].notnull() & df['addr_wd'].notnull()

# fill in motherhood columns
df.loc[mask,'sp_is_mom'] = [checkWDRelation(row.addr_wd, row.spkr_wd, 'P25', cache=wd_cache) 
                                for row in df.loc[mask,].itertuples()]
df.loc[mask,'ad_is_mom'] = [checkWDRelation(row.spkr_wd, row.addr_wd, 'P25', cache=wd_cache) 
                                for row in df.loc[mask,].itertuples()]

# %% [markdown]
# 🤔 Let's take a look at the results. Here is the complete set of speeches, with the additional attribute `sp_is_mom` if the speaker is the addressee's mother, and `ad_is_mom` if the addressee is the speaker's mother.
#
# As a quick sanity check, the first two speeches in the Argonautica, which were at the top of the list when I ran this, are between Jason and his mother, Alcimede.

# %%
df.loc[df.work=='Argonautica']
# Out:
#        id         work l_first  l_last      spkr   spkr_wd       addr
# 0    1385  Argonautica   1.242   1.246  citizens      None   citizens  \
# 1    1386  Argonautica   1.251   1.259   someone      None    someone
# 2    1387  Argonautica   1.278   1.291  Alcimede  Q2718542      Jason
# 3    1388  Argonautica   1.295   1.305     Jason   Q176758   Alcimede
# 4    1389  Argonautica   1.332   1.340     Jason   Q176758  Argonauts
# ..    ...          ...     ...     ...       ...       ...        ...
# 138  1523  Argonautica  4.1573  4.1600    Triton   Q148030  Argonauts
# 139  1524  Argonautica  4.1597  4.1600     Jason   Q176758     Triton
# 140  1525  Argonautica  4.1654  4.1658     Medea   Q174278  Argonauts
# 141  1526  Argonautica  4.1741  4.1745  Calliste      None   Euphemus
# 142  1527  Argonautica  4.1749  4.1754     Jason   Q176758   Euphemus
#
#       addr_wd sp_is_mom ad_is_mom
# 0        None      None      None
# 1        None      None      None
# 2     Q176758      True     False
# 3    Q2718542     False      True
# 4     Q165510     False     False
# ..        ...       ...       ...
# 138   Q165510     False     False
# 139   Q148030     False     False
# 140   Q165510     False     False
# 141   Q749123      None      None
# 142   Q749123     False     False
#
# [153 rows x 10 columns]

# %% [markdown]
# Thanks to pandas, we can filter the data frame on the new boolean columns to show only speeches between mother and child.

# %%
hits = df.loc[df.sp_is_mom | df.ad_is_mom,
             ['work', 'l_first', 'l_last', 'spkr', 'addr']]
hits
# Out:
#              work l_first  l_last        spkr                    addr
# 2     Argonautica   1.278   1.291    Alcimede                   Jason
# 3     Argonautica   1.295   1.305       Jason                Alcimede
# 70    Argonautica   3.129   3.144   Aphrodite                    Eros
# 71    Argonautica   3.151   3.153   Aphrodite                    Eros
# 73    Argonautica   3.260   3.267   Chalciope  Argus (son of Phrixus)
# 164         Iliad   1.352   1.356    Achilles                  Thetis
# 165         Iliad   1.362   1.363      Thetis                Achilles
# 166         Iliad   1.365   1.412    Achilles                  Thetis
# 167         Iliad   1.414   1.427      Thetis                Achilles
# 178         Iliad   1.586   1.594  Hephaestus                    Hera
# 271         Iliad   5.373   5.374       Dione               Aphrodite
# 272         Iliad   5.376   5.380   Aphrodite                   Dione
# 273         Iliad   5.382   5.415       Dione               Aphrodite
# 303         Iliad   6.254   6.262      Hecuba                  Hector
# 304         Iliad   6.264   6.285      Hector                  Hecuba
# 625         Iliad   18.73   18.77      Thetis                Achilles
# 626         Iliad   18.79   18.93    Achilles                  Thetis
# 627         Iliad   18.95   18.96      Thetis                Achilles
# 628         Iliad   18.98  18.126    Achilles                  Thetis
# 629         Iliad  18.128  18.137      Thetis                Achilles
# 647         Iliad    19.8   19.11      Thetis                Achilles
# 648         Iliad   19.21   19.27    Achilles                  Thetis
# 649         Iliad   19.29   19.36      Thetis                Achilles
# 703         Iliad  21.331  21.341        Hera              Hephaestus
# 706         Iliad  21.379  21.380        Hera              Hephaestus
# 724         Iliad   22.82   22.89      Hecuba                  Hector
# 746         Iliad  22.431  22.436      Hecuba                  Hector
# 800         Iliad  24.128  24.137      Thetis                Achilles
# 801         Iliad  24.139  24.140    Achilles                  Thetis
# 838         Iliad  24.748  24.759      Hecuba                  Hector
# 855       Odyssey   1.346   1.359  Telemachus                Penelope
# 1088      Odyssey  11.155  11.162    Anticlea                Odysseus
# 1089      Odyssey  11.164  11.179    Odysseus                Anticlea
# 1090      Odyssey  11.181  11.203    Anticlea                Odysseus
# 1091      Odyssey  11.210  11.214    Odysseus                Anticlea
# 1092      Odyssey  11.216  11.224    Anticlea                Odysseus
# 1244      Odyssey   17.41   17.44    Penelope              Telemachus
# 1245      Odyssey   17.46   17.56  Telemachus                Penelope
# 1248      Odyssey  17.101  17.106    Penelope              Telemachus
# 1249      Odyssey  17.108  17.149  Telemachus                Penelope
# 1311      Odyssey  18.215  18.225    Penelope              Telemachus
# 1312      Odyssey  18.227  18.242  Telemachus                Penelope
# 1412      Odyssey  21.344  21.353  Telemachus                Penelope
# 1465      Odyssey   23.97  23.103  Telemachus                Penelope
# 1466      Odyssey  23.105  23.110    Penelope              Telemachus
# 1522       Aeneid   1.321   1.324       Venus                  Aeneas
# 1523       Aeneid   1.326   1.334      Aeneas                   Venus
# 1524       Aeneid   1.335   1.370       Venus                  Aeneas
# 1525       Aeneid   1.372   1.385      Aeneas                   Venus
# 1526       Aeneid   1.387   1.401       Venus                  Aeneas
# 1527       Aeneid   1.407   1.409      Aeneas                   Venus
# 1535       Aeneid   1.664   1.688       Venus                    Amor
# 1557       Aeneid   2.594   2.620       Venus                  Aeneas
# 1559       Aeneid   2.657   2.670      Aeneas                   Venus
# 1652       Aeneid   6.194   6.197      Aeneas                   Venus
# 1718       Aeneid   8.612   8.614       Venus                  Aeneas

# %% [markdown]
# Pandas also comes in handy if I wanted to export this data to Excel:

# %%
hits.to_csv('example.csv')

# %% [markdown]
# ### Validation
#
# Let's see how well the automated approach worked. We'll load up a hand-corrected list of mother-child speeches and compare.

# %%
bench = pd.read_csv('data/moms-bench.csv', dtype=str)
bench
# Out:
#       work l_first l_last              spkr                 addr
# 0    Iliad   1.352    356          Achilles               Thetis
# 1    Iliad   1.362    363            Thetis             Achilles
# 2    Iliad   1.365    412          Achilles               Thetis
# 3    Iliad   1.414    427            Thetis             Achilles
# 4    Iliad   1.586    594        Hephaestus                 Hera
# ..     ...     ...    ...               ...                  ...
# 56  Aeneid   6.194    197            Aeneas  two doves and Venus
# 57  Aeneid   8.612    614             Venus               Aeneas
# 58  Aeneid    9.83     92            Cybele              Jupiter
# 59  Aeneid    9.94    103           Jupiter               Cybele
# 60  Aeneid   9.481    497  Euryalus' mother             Euryalus
#
# [61 rows x 5 columns]

# %% [markdown]
# Let's look at the union of `hits` and `bench` to see how we did:

# %%
results = hits.merge(bench, on=['work', 'l_first'], how='outer', 
                        suffixes=['_h', '_b'], indicator=True)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(results[['work', 'l_first', 'spkr_h', 'addr_h', 'spkr_b', 'addr_b', '_merge']])
# Out:
#            work l_first      spkr_h                  addr_h
# 0   Argonautica   1.278    Alcimede                   Jason  \
# 1   Argonautica   1.295       Jason                Alcimede
# 2   Argonautica   3.129   Aphrodite                    Eros
# 3   Argonautica   3.151   Aphrodite                    Eros
# 4   Argonautica   3.260   Chalciope  Argus (son of Phrixus)
# 5         Iliad   1.352    Achilles                  Thetis
# 6         Iliad   1.362      Thetis                Achilles
# 7         Iliad   1.365    Achilles                  Thetis
# 8         Iliad   1.414      Thetis                Achilles
# 9         Iliad   1.586  Hephaestus                    Hera
# 10        Iliad   5.373       Dione               Aphrodite
# 11        Iliad   5.376   Aphrodite                   Dione
# 12        Iliad   5.382       Dione               Aphrodite
# 13        Iliad   6.254      Hecuba                  Hector
# 14        Iliad   6.264      Hector                  Hecuba
# 15        Iliad   18.73      Thetis                Achilles
# 16        Iliad   18.79    Achilles                  Thetis
# 17        Iliad   18.95      Thetis                Achilles
# 18        Iliad   18.98    Achilles                  Thetis
# 19        Iliad  18.128      Thetis                Achilles
# 20        Iliad    19.8      Thetis                Achilles
# 21        Iliad   19.21    Achilles                  Thetis
# 22        Iliad   19.29      Thetis                Achilles
# 23        Iliad  21.331        Hera              Hephaestus
# 24        Iliad  21.379        Hera              Hephaestus
# 25        Iliad   22.82      Hecuba                  Hector
# 26        Iliad  22.431      Hecuba                  Hector
# 27        Iliad  24.128      Thetis                Achilles
# 28        Iliad  24.139    Achilles                  Thetis
# 29        Iliad  24.748      Hecuba                  Hector
# 30      Odyssey   1.346  Telemachus                Penelope
# 31      Odyssey  11.155    Anticlea                Odysseus
# 32      Odyssey  11.164    Odysseus                Anticlea
# 33      Odyssey  11.181    Anticlea                Odysseus
# 34      Odyssey  11.210    Odysseus                Anticlea
# 35      Odyssey  11.216    Anticlea                Odysseus
# 36      Odyssey   17.41    Penelope              Telemachus
# 37      Odyssey   17.46  Telemachus                Penelope
# 38      Odyssey  17.101    Penelope              Telemachus
# 39      Odyssey  17.108  Telemachus                Penelope
# 40      Odyssey  18.215    Penelope              Telemachus
# 41      Odyssey  18.227  Telemachus                Penelope
# 42      Odyssey  21.344  Telemachus                Penelope
# 43      Odyssey   23.97  Telemachus                Penelope
# 44      Odyssey  23.105    Penelope              Telemachus
# 45       Aeneid   1.321       Venus                  Aeneas
# 46       Aeneid   1.326      Aeneas                   Venus
# 47       Aeneid   1.335       Venus                  Aeneas
# 48       Aeneid   1.372      Aeneas                   Venus
# 49       Aeneid   1.387       Venus                  Aeneas
# 50       Aeneid   1.407      Aeneas                   Venus
# 51       Aeneid   1.664       Venus                    Amor
# 52       Aeneid   2.594       Venus                  Aeneas
# 53       Aeneid   2.657      Aeneas                   Venus
# 54       Aeneid   6.194      Aeneas                   Venus
# 55       Aeneid   8.612       Venus                  Aeneas
# 56        Iliad  15.104         NaN                     NaN
# 57        Iliad  15.115         NaN                     NaN
# 58       Aeneid    9.83         NaN                     NaN
# 59       Aeneid    9.94         NaN                     NaN
# 60       Aeneid   9.481         NaN                     NaN
#
#                  spkr_b                          addr_b      _merge
# 0              Alcimede                           Jason        both
# 1                 Jason                        Alcimede        both
# 2             Aphrodite                            Eros        both
# 3             Aphrodite                            Eros        both
# 4             Chalciope                           Argus        both
# 5              Achilles                          Thetis        both
# 6                Thetis                        Achilles        both
# 7              Achilles                          Thetis        both
# 8                Thetis                        Achilles        both
# 9            Hephaestus                            Hera        both
# 10                Dione                       Aphrodite        both
# 11            Aphrodite                           Dione        both
# 12                Dione                       Aphrodite        both
# 13               Hecuba                          Hector        both
# 14               Hector                          Hecuba        both
# 15               Thetis                        Achilles        both
# 16             Achilles                          Thetis        both
# 17               Thetis                        Achilles        both
# 18             Achilles                          Thetis        both
# 19               Thetis                        Achilles        both
# 20               Thetis                        Achilles        both
# 21             Achilles                          Thetis        both
# 22               Thetis                        Achilles        both
# 23                 Hera                      Hephaestus        both
# 24                 Hera                      Hephaestus        both
# 25               Hecuba                          Hector        both
# 26               Hecuba                          Hector        both
# 27               Thetis                        Achilles        both
# 28             Achilles                          Thetis        both
# 29               Hecuba                          Hector        both
# 30           Telemachus                        Penelope        both
# 31             Anticlea                        Odysseus        both
# 32             Odysseus                        Anticlea        both
# 33             Anticlea                        Odysseus        both
# 34             Odysseus                        Anticlea        both
# 35             Anticlea                        Odysseus        both
# 36             Penelope                      Telemachus        both
# 37           Telemachus                        Penelope        both
# 38             Penelope                      Telemachus        both
# 39           Telemachus                        Penelope        both
# 40             Penelope                      Telemachus        both
# 41           Telemachus                        Penelope        both
# 42           Telemachus                        Penelope        both
# 43           Telemachus                        Penelope        both
# 44             Penelope                      Telemachus        both
# 45  Venus (in disguise)              Aeneas and Achates        both
# 46               Aeneas                           Venus        both
# 47  Venus (in disguise)                          Aeneas        both
# 48               Aeneas                           Venus        both
# 49                Venus                         Aeneas         both
# 50               Aeneas                           Venus        both
# 51                Venus                          Cupido        both
# 52                Venus                          Aeneas        both
# 53               Aeneas  Anchises and Venus and Trojans        both
# 54               Aeneas             two doves and Venus        both
# 55                Venus                          Aeneas        both
# 56                 Hera                            gods  right_only
# 57                 Ares                            gods  right_only
# 58               Cybele                         Jupiter  right_only
# 59              Jupiter                          Cybele  right_only
# 60     Euryalus' mother                        Euryalus  right_only

# %% [markdown]
# #### Precision and Recall

# %%
true_pos = sum(results['_merge'] == 'both')

p = true_pos / hits.shape[0]
r = true_pos / bench.shape[0]

print(f'Precision: {p:.2f}')
print(f'Recall:    {r:.2f}')
# Out:
# Precision: 1.00
# Recall:    0.92

# %% [markdown]
# ### Discussion
#
# #### The good news
# We got almost all of the benchmark set, with exceptions to be discussed below, and no false positives.
#
# #### The bad news
# Let's look a little more closely at the speeches we missed:

# %%
missed = results[results['_merge'] == 'right_only'][
                ['work', 'l_first', 'spkr_h', 'addr_h', 'spkr_b', 'addr_b']]
missed
# Out:
#       work l_first spkr_h addr_h            spkr_b    addr_b
# 56   Iliad  15.104    NaN    NaN              Hera      gods
# 57   Iliad  15.115    NaN    NaN              Ares      gods
# 58  Aeneid    9.83    NaN    NaN            Cybele   Jupiter
# 59  Aeneid    9.94    NaN    NaN           Jupiter    Cybele
# 60  Aeneid   9.481    NaN    NaN  Euryalus' mother  Euryalus

# %% [markdown]
# At a glance, I'd say these fall into three groups:
#
#  1. A conversation in the Iliad between Hera and a group of gods, some of whom were here children
#  2. A conversation in the Aeneid between Jupiter and "Cybele," i.e., Rhea.
#  3. A conversation in the Aeneid between Euryalus and his anonymous mother.
#
# #### Digging a little deeper
#
# First, let's confirm that all these speeches are in the database results.

# %%
missed.merge(df, how='left', on=['work', 'l_first'])[[
    'work', 'l_first',                           # - common to both
    'id', 'spkr', 'addr', 'spkr_wd', 'addr_wd',  # - from df
            'sp_is_mom', 'ad_is_mom',            #
    'spkr_b', 'addr_b'                           # - from bench
]]
# Out:
#      work l_first    id                       spkr               addr
# 0   Iliad  15.104   391                       Hera               gods  \
# 1   Iliad  15.115   392                       Ares               gods
# 2  Aeneid    9.83  1737                     Cybele            Jupiter
# 3  Aeneid    9.94  1738                    Jupiter             Cybele
# 4  Aeneid   9.481  1758  Euryalus' mother (Aeneid)  Euryalus (Aeneid)
# 5  Aeneid   9.481  1758  Euryalus' mother (Aeneid)            Jupiter
# 6  Aeneid   9.481  1758  Euryalus' mother (Aeneid)          Rutulians
#
#    spkr_wd    addr_wd sp_is_mom ad_is_mom            spkr_b    addr_b
# 0   Q38012       None      None      None              Hera      gods
# 1   Q40901       None      None      None              Ares      gods
# 2  Q188236     Q34201     False     False            Cybele   Jupiter
# 3   Q34201    Q188236     False     False           Jupiter    Cybele
# 4     None  Q16647668      None      None  Euryalus' mother  Euryalus
# 5     None     Q34201      None      None  Euryalus' mother  Euryalus
# 6     None       None      None      None  Euryalus' mother  Euryalus

# %% [markdown]
# The apostrophe to Euryalus by his mother is in the data from DICES, but what we don’t have is a WikiData ID for her. She’s treated as an anonymous character--along with many other persons described only by a family relation or an occupation--and as of this writing, anonymous speakers and addressees are recorded only as CharacterInstances, without an underlying Character object.
#
# The conversation between Hera and the gods is also there in the results from DICES, but again "gods" doesn't have a WikiData ID. In this case the difficulty as far as DICES is concerned is that collectives can’t currently be broken down into their membership, some of which in this case would have WikiData IDs. On the other hand, if WikiData has a dedicated record for the collective that also includes parent relations, we could work around this.
#
# The conversation between Jupiter and his mom is in the database, and each of these characters is matched with a WikiData entity, but we're not getting the right answer about their kinship relation because Virgil is being poetic here and conflating two goddesses: Rhea, the mother of Zeus, and Cybele, the Phrygian goddess with whom she was sometimes identified. WikiData has distinct entities for the Rhea and Cybele, and only the former is recorded as Zeus’s mother. We can fix this by pointing the character's WikiData ID to the Greek goddess instead (as we did for the Roman deities), but maybe we should think about the larger problem of poetic ambiguity/metonymy/syncretism.

# %% [markdown]
# ### Takeaways
#
#  - WikiData gave us a lot for free -- all of the individual mother-child relationships were in there when we knew where to look.
#
#  - There is still some important work to be done refining our underlying data model.
#
#  - If we want to rely on linked open data for high-stakes work, we need resources that are sensitive to the details we care about. We hope that MANTO, because it's specific to Classical myth and hand-curated by domain experts, can help us with problems like when to treat Cybele and Rhea as independent entities and when to consider them identical.
